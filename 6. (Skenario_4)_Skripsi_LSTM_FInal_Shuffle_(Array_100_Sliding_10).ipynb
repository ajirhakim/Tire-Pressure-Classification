# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Load the data &inspect data
data = pd.read_csv('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/undersampled_data.csv')
data.head()
# Out:
#    AccX  AccY  AccZ  GyroX  GyroY  GyroZ                Label
# 0  0.15  0.03  1.04  -0.09  -0.04  -0.03  Ban Belakang Kempes
# 1  0.16  0.05  1.03  -0.09   0.00  -0.03  Ban Belakang Kempes
# 2  0.15  0.03  1.03  -0.09   0.02  -0.02  Ban Belakang Kempes
# 3  0.12  0.03  1.03  -0.09   0.00  -0.02  Ban Belakang Kempes
# 4  0.14  0.03  1.04  -0.09  -0.03  -0.03  Ban Belakang Kempes

# %%
# Encode labels
le = LabelEncoder()
data['label_encoded'] = le.fit_transform(data['Label'])

# %%
def split_into_segments(df, segment_length=10, sampling_rate=0.1, step=10):
    samples_per_segment = int(segment_length / sampling_rate)
    segments = []
    labels = []

    for start in range(0, len(df) - samples_per_segment, step):  # Sliding window 10 sampel
        end = start + samples_per_segment
        segment = df.iloc[start:end]

        if len(segment) == samples_per_segment:
            label_mode = segment['label_encoded'].mode()[0]
            if len(segment['label_encoded'].unique()) == 1:  # Pastikan hanya ada satu label dalam segmen
                segments.append(segment[['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ']].values)
                labels.append(label_mode)
            else:
                continue  # Lanjutkan ke window berikutnya jika label lebih dari satu

    return np.array(segments), np.array(labels)

# %%
# Membagi data menjadi segmen-segmen
X, y = split_into_segments(data)

# %%
# One-hot encoding for labels
y = to_categorical(y, num_classes=4)

# %%
# Splitting data into training and testing using stratified split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Menghitung jumlah sampel per label di data pelatihan
unique_train, counts_train = np.unique(np.argmax(y_train, axis=1), return_counts=True)

# Menghitung jumlah sampel per label di data pengujian
unique_test, counts_test = np.unique(np.argmax(y_test, axis=1), return_counts=True)

# Membuat plot distribusi label
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.barplot(x=unique_train, y=counts_train, ax=ax[0])
ax[0].set_title('Distribusi Label pada Data Pelatihan')
ax[0].set_xlabel('Label')
ax[0].set_ylabel('Jumlah Sampel')

sns.barplot(x=unique_test, y=counts_test, ax=ax[1])
ax[1].set_title('Distribusi Label pada Data Pengujian')
ax[1].set_xlabel('Label')
ax[1].set_ylabel('Jumlah Sampel')

plt.tight_layout()
plt.show()

# %%
# Creating the LSTM model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# %%
# Second LSTM layer
model.add(LSTM(50, return_sequences=True))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# %%
# Third LSTM layer
model.add(LSTM(25))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# %%
# Adding a Dense output layer
model.add(Dense(4, activation='softmax'))

# %%
# Compiling the model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 100)          42800
#
#  batch_normalization (Batch  (None, 100, 100)          400
#  Normalization)
#
#  dropout (Dropout)           (None, 100, 100)          0
#
#  lstm_1 (LSTM)               (None, 100, 50)           30200
#
#  batch_normalization_1 (Bat  (None, 100, 50)           200
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 100, 50)           0
#
#  lstm_2 (LSTM)               (None, 25)                7600
#
#  batch_normalization_2 (Bat  (None, 25)                100
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 25)                0
#
#  dense (Dense)               (None, 4)                 104
#
# =================================================================
# Total params: 81404 (317.98 KB)
# Trainable params: 81054 (316.62 KB)
# Non-trainable params: 350 (1.37 KB)
# _________________________________________________________________

# %%
# Using early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %%
# Training the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/50
# 601/601 [==============================] - 130s 203ms/step - loss: 1.4081 - accuracy: 0.3594 - val_loss: 1.7927 - val_accuracy: 0.2629
# Epoch 2/50
# 601/601 [==============================] - 121s 202ms/step - loss: 1.2291 - accuracy: 0.4619 - val_loss: 1.4382 - val_accuracy: 0.2908
# Epoch 3/50
# 601/601 [==============================] - 115s 192ms/step - loss: 1.0759 - accuracy: 0.5465 - val_loss: 1.6356 - val_accuracy: 0.3551
# Epoch 4/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.9287 - accuracy: 0.6195 - val_loss: 1.2358 - val_accuracy: 0.4801
# Epoch 5/50
# 601/601 [==============================] - 115s 191ms/step - loss: 0.8035 - accuracy: 0.6779 - val_loss: 1.3612 - val_accuracy: 0.4781
# Epoch 6/50
# 601/601 [==============================] - 121s 201ms/step - loss: 0.7103 - accuracy: 0.7227 - val_loss: 1.2766 - val_accuracy: 0.4974
# Epoch 7/50
# 601/601 [==============================] - 115s 192ms/step - loss: 0.6253 - accuracy: 0.7585 - val_loss: 1.9420 - val_accuracy: 0.4238
# Epoch 8/50
# 601/601 [==============================] - 120s 200ms/step - loss: 0.5516 - accuracy: 0.7890 - val_loss: 4.1145 - val_accuracy: 0.2960
# Epoch 9/50
# 601/601 [==============================] - 116s 193ms/step - loss: 0.4871 - accuracy: 0.8192 - val_loss: 1.5358 - val_accuracy: 0.5088
# Epoch 10/50
# 601/601 [==============================] - 120s 199ms/step - loss: 0.4409 - accuracy: 0.8380 - val_loss: 0.8966 - val_accuracy: 0.6576
# Epoch 11/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.3881 - accuracy: 0.8572 - val_loss: 2.0608 - val_accuracy: 0.4171
# Epoch 12/50
# 601/601 [==============================] - 121s 202ms/step - loss: 0.3394 - accuracy: 0.8747 - val_loss: 1.6646 - val_accuracy: 0.4943
# Epoch 13/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.3161 - accuracy: 0.8827 - val_loss: 2.2764 - val_accuracy: 0.4930
# Epoch 14/50
# 601/601 [==============================] - 120s 199ms/step - loss: 0.2924 - accuracy: 0.8946 - val_loss: 1.7928 - val_accuracy: 0.4674
# Epoch 15/50
# 601/601 [==============================] - 115s 192ms/step - loss: 0.2586 - accuracy: 0.9091 - val_loss: 0.5814 - val_accuracy: 0.8032
# Epoch 16/50
# 601/601 [==============================] - 119s 198ms/step - loss: 0.2401 - accuracy: 0.9151 - val_loss: 0.7519 - val_accuracy: 0.7387
# Epoch 17/50
# 601/601 [==============================] - 117s 195ms/step - loss: 0.2145 - accuracy: 0.9253 - val_loss: 1.7761 - val_accuracy: 0.4970
# Epoch 18/50
# 601/601 [==============================] - 120s 200ms/step - loss: 0.1953 - accuracy: 0.9308 - val_loss: 0.6280 - val_accuracy: 0.7920
# Epoch 19/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.1906 - accuracy: 0.9333 - val_loss: 1.0243 - val_accuracy: 0.7314
# Epoch 20/50
# 601/601 [==============================] - 117s 194ms/step - loss: 0.1787 - accuracy: 0.9376 - val_loss: 0.9150 - val_accuracy: 0.7316
# Epoch 21/50
# 601/601 [==============================] - 119s 198ms/step - loss: 0.1641 - accuracy: 0.9434 - val_loss: 2.4709 - val_accuracy: 0.4579
# Epoch 22/50
# 601/601 [==============================] - 121s 202ms/step - loss: 0.1555 - accuracy: 0.9474 - val_loss: 1.5878 - val_accuracy: 0.6382
# Epoch 23/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.1457 - accuracy: 0.9507 - val_loss: 0.9157 - val_accuracy: 0.7620
# Epoch 24/50
# 601/601 [==============================] - 120s 200ms/step - loss: 0.1388 - accuracy: 0.9519 - val_loss: 0.7928 - val_accuracy: 0.7730
# Epoch 25/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.1475 - accuracy: 0.9493 - val_loss: 0.8391 - val_accuracy: 0.7499
# Epoch 26/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.1218 - accuracy: 0.9591 - val_loss: 1.7166 - val_accuracy: 0.6170
# Epoch 27/50
# 601/601 [==============================] - 119s 198ms/step - loss: 0.1283 - accuracy: 0.9576 - val_loss: 0.5081 - val_accuracy: 0.8196
# Epoch 28/50
# 601/601 [==============================] - 121s 202ms/step - loss: 0.1235 - accuracy: 0.9582 - val_loss: 0.3324 - val_accuracy: 0.8952
# Epoch 29/50
# 601/601 [==============================] - 119s 197ms/step - loss: 0.1231 - accuracy: 0.9609 - val_loss: 0.6284 - val_accuracy: 0.8298
# Epoch 30/50
# 601/601 [==============================] - 120s 199ms/step - loss: 0.1092 - accuracy: 0.9637 - val_loss: 0.3763 - val_accuracy: 0.8885
# Epoch 31/50
# 601/601 [==============================] - 117s 195ms/step - loss: 0.1049 - accuracy: 0.9661 - val_loss: 0.8095 - val_accuracy: 0.7895
# Epoch 32/50
# 601/601 [==============================] - 119s 197ms/step - loss: 0.1061 - accuracy: 0.9658 - val_loss: 0.5321 - val_accuracy: 0.8406
# Epoch 33/50
# 601/601 [==============================] - 113s 189ms/step - loss: 0.0974 - accuracy: 0.9676 - val_loss: 1.4695 - val_accuracy: 0.6807
# Epoch 34/50
# 601/601 [==============================] - 121s 201ms/step - loss: 0.0949 - accuracy: 0.9688 - val_loss: 0.2678 - val_accuracy: 0.9118
# Epoch 35/50
# 601/601 [==============================] - 115s 191ms/step - loss: 0.0977 - accuracy: 0.9686 - val_loss: 0.2371 - val_accuracy: 0.9249
# Epoch 36/50
# 601/601 [==============================] - 118s 197ms/step - loss: 0.0903 - accuracy: 0.9701 - val_loss: 1.0692 - val_accuracy: 0.7603
# Epoch 37/50
# 601/601 [==============================] - 117s 195ms/step - loss: 0.0851 - accuracy: 0.9722 - val_loss: 0.3563 - val_accuracy: 0.9004
# Epoch 38/50
# 601/601 [==============================] - 117s 195ms/step - loss: 0.0921 - accuracy: 0.9693 - val_loss: 1.5068 - val_accuracy: 0.6651
# Epoch 39/50
# 601/601 [==============================] - 118s 197ms/step - loss: 0.0820 - accuracy: 0.9727 - val_loss: 0.8490 - val_accuracy: 0.7780
# Epoch 40/50
# 601/601 [==============================] - 119s 198ms/step - loss: 0.0830 - accuracy: 0.9730 - val_loss: 0.7278 - val_accuracy: 0.8165
# Epoch 41/50
# 601/601 [==============================] - 118s 197ms/step - loss: 0.0812 - accuracy: 0.9741 - val_loss: 0.9737 - val_accuracy: 0.7656
# Epoch 42/50
# 601/601 [==============================] - 118s 197ms/step - loss: 0.0880 - accuracy: 0.9720 - val_loss: 0.7602 - val_accuracy: 0.7988
# Epoch 43/50
# 601/601 [==============================] - 118s 197ms/step - loss: 0.0717 - accuracy: 0.9767 - val_loss: 0.9073 - val_accuracy: 0.7641
# Epoch 44/50
# 601/601 [==============================] - 119s 198ms/step - loss: 0.0760 - accuracy: 0.9749 - val_loss: 0.1723 - val_accuracy: 0.9482
# Epoch 45/50
# 601/601 [==============================] - 117s 195ms/step - loss: 0.0780 - accuracy: 0.9755 - val_loss: 0.2961 - val_accuracy: 0.9220
# Epoch 46/50
# 601/601 [==============================] - 119s 198ms/step - loss: 0.0751 - accuracy: 0.9758 - val_loss: 0.2406 - val_accuracy: 0.9282
# Epoch 47/50
# 601/601 [==============================] - 117s 195ms/step - loss: 0.0741 - accuracy: 0.9763 - val_loss: 0.1834 - val_accuracy: 0.9405
# Epoch 48/50
# 601/601 [==============================] - 117s 194ms/step - loss: 0.0694 - accuracy: 0.9780 - val_loss: 0.5271 - val_accuracy: 0.8625
# Epoch 49/50
# 601/601 [==============================] - 117s 195ms/step - loss: 0.0751 - accuracy: 0.9765 - val_loss: 0.1886 - val_accuracy: 0.9357
# Epoch 50/50
# 601/601 [==============================] - 118s 196ms/step - loss: 0.0583 - accuracy: 0.9818 - val_loss: 0.6191 - val_accuracy: 0.8714

# %%
# Evaluasi model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 151/151 [==============================] - 9s 48ms/step

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Classification report
print(classification_report(y_true, y_pred_classes, target_names=le.classes_))
# Out:
#                      precision    recall  f1-score   support
#
# Ban Belakang Kempes       0.95      0.95      0.95      1202
#    Ban Depan Kempes       0.87      0.85      0.86      1202
#          Ban Normal       0.97      0.72      0.83      1202
#    Kedua Ban Kempes       0.75      0.96      0.85      1201
#
#            accuracy                           0.87      4807
#           macro avg       0.89      0.87      0.87      4807
#        weighted avg       0.89      0.87      0.87      4807

# %%
# Plotting training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
# Plotting training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Save the model for deployment
model.save('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/model_shuffle_100-10.keras')

# %%
# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/model_shuffle_100-10.keras')

# %%
# Convert the model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter._experimental_lower_tensor_list_ops = False
tflite_model = converter.convert()

# %%
# Save the TensorFlow Lite model to a file
with open('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/model_shuffle_100-10.tflite', 'wb') as f:
    f.write(tflite_model)

print("Model has been converted to TensorFlow Lite and saved.")
# Out:
# Model has been converted to TensorFlow Lite and saved.
