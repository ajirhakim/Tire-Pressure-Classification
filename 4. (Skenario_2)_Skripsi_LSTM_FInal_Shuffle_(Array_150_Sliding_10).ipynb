# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, StratifiedKFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report
import tensorflow as tf
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# Load the data &inspect data
data = pd.read_csv('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/undersampled_data.csv')
data.head()
# Out:
#    AccX  AccY  AccZ  GyroX  GyroY  GyroZ                Label
# 0  0.15  0.03  1.04  -0.09  -0.04  -0.03  Ban Belakang Kempes
# 1  0.16  0.05  1.03  -0.09   0.00  -0.03  Ban Belakang Kempes
# 2  0.15  0.03  1.03  -0.09   0.02  -0.02  Ban Belakang Kempes
# 3  0.12  0.03  1.03  -0.09   0.00  -0.02  Ban Belakang Kempes
# 4  0.14  0.03  1.04  -0.09  -0.03  -0.03  Ban Belakang Kempes

# %%
# Encode labels
le = LabelEncoder()
data['label_encoded'] = le.fit_transform(data['Label'])

# %%
def split_into_segments(df, segment_length=15, sampling_rate=0.1, step=10):
    samples_per_segment = int(segment_length / sampling_rate)
    segments = []
    labels = []

    for start in range(0, len(df) - samples_per_segment, step):  # Sliding window 10 sampel
        end = start + samples_per_segment
        segment = df.iloc[start:end]

        if len(segment) == samples_per_segment:
            label_mode = segment['label_encoded'].mode()[0]
            if len(segment['label_encoded'].unique()) == 1:  # Pastikan hanya ada satu label dalam segmen
                segments.append(segment[['AccX', 'AccY', 'AccZ', 'GyroX', 'GyroY', 'GyroZ']].values)
                labels.append(label_mode)
            else:
                continue  # Lanjutkan ke window berikutnya jika label lebih dari satu

    return np.array(segments), np.array(labels)

# %%
# Membagi data menjadi segmen-segmen
X, y = split_into_segments(data)

# %%
# One-hot encoding for labels
y = to_categorical(y, num_classes=4)

# %%
# Splitting data into training and testing using stratified split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %%
X_train.shape
# Out:
# (19208, 150, 6)

# %%
# Menghitung jumlah sampel per label di data pelatihan
unique_train, counts_train = np.unique(np.argmax(y_train, axis=1), return_counts=True)

# Menghitung jumlah sampel per label di data pengujian
unique_test, counts_test = np.unique(np.argmax(y_test, axis=1), return_counts=True)

# Membuat plot distribusi label
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.barplot(x=unique_train, y=counts_train, ax=ax[0])
ax[0].set_title('Distribusi Label pada Data Pelatihan')
ax[0].set_xlabel('Label')
ax[0].set_ylabel('Jumlah Sampel')

sns.barplot(x=unique_test, y=counts_test, ax=ax[1])
ax[1].set_title('Distribusi Label pada Data Pengujian')
ax[1].set_xlabel('Label')
ax[1].set_ylabel('Jumlah Sampel')

plt.tight_layout()
plt.show()

# %%
# Creating the LSTM model
model = Sequential()
model.add(LSTM(100, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# %%
# Second LSTM layer
model.add(LSTM(50, return_sequences=True))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# %%
# Third LSTM layer
model.add(LSTM(25))
model.add(BatchNormalization())
model.add(Dropout(0.2))

# %%
# Adding a Dense output layer
model.add(Dense(4, activation='softmax'))

# %%
# Compiling the model
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Model summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 150, 100)          42800
#
#  batch_normalization (Batch  (None, 150, 100)          400
#  Normalization)
#
#  dropout (Dropout)           (None, 150, 100)          0
#
#  lstm_1 (LSTM)               (None, 150, 50)           30200
#
#  batch_normalization_1 (Bat  (None, 150, 50)           200
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 150, 50)           0
#
#  lstm_2 (LSTM)               (None, 25)                7600
#
#  batch_normalization_2 (Bat  (None, 25)                100
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 25)                0
#
#  dense (Dense)               (None, 4)                 104
#
# =================================================================
# Total params: 81404 (317.98 KB)
# Trainable params: 81054 (316.62 KB)
# Non-trainable params: 350 (1.37 KB)
# _________________________________________________________________

# %%
# Using early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=20, restore_best_weights=True)

# %%
# Training the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), callbacks=[early_stopping], verbose=1)
# Out:
# Epoch 1/50
# 601/601 [==============================] - 195s 311ms/step - loss: 1.4138 - accuracy: 0.3659 - val_loss: 1.5226 - val_accuracy: 0.3096
# Epoch 2/50
# 601/601 [==============================] - 176s 292ms/step - loss: 1.2499 - accuracy: 0.4416 - val_loss: 1.5743 - val_accuracy: 0.2942
# Epoch 3/50
# 601/601 [==============================] - 187s 312ms/step - loss: 1.1168 - accuracy: 0.5215 - val_loss: 1.4775 - val_accuracy: 0.2517
# Epoch 4/50
# 601/601 [==============================] - 194s 322ms/step - loss: 1.1091 - accuracy: 0.5204 - val_loss: 1.5991 - val_accuracy: 0.2509
# Epoch 5/50
# 601/601 [==============================] - 197s 328ms/step - loss: 0.8413 - accuracy: 0.6588 - val_loss: 2.1850 - val_accuracy: 0.2555
# Epoch 6/50
# 601/601 [==============================] - 195s 325ms/step - loss: 0.7087 - accuracy: 0.7193 - val_loss: 1.1840 - val_accuracy: 0.5211
# Epoch 7/50
# 601/601 [==============================] - 191s 317ms/step - loss: 0.5826 - accuracy: 0.7729 - val_loss: 2.2104 - val_accuracy: 0.3165
# Epoch 8/50
# 601/601 [==============================] - 187s 311ms/step - loss: 0.5056 - accuracy: 0.8067 - val_loss: 4.1983 - val_accuracy: 0.2534
# Epoch 9/50
# 601/601 [==============================] - 185s 307ms/step - loss: 0.4266 - accuracy: 0.8388 - val_loss: 2.4902 - val_accuracy: 0.3610
# Epoch 10/50
# 601/601 [==============================] - 184s 306ms/step - loss: 0.3667 - accuracy: 0.8650 - val_loss: 1.5091 - val_accuracy: 0.5338
# Epoch 11/50
# 601/601 [==============================] - 186s 309ms/step - loss: 0.3153 - accuracy: 0.8833 - val_loss: 2.4082 - val_accuracy: 0.4805
# Epoch 12/50
# 601/601 [==============================] - 184s 306ms/step - loss: 0.2717 - accuracy: 0.9043 - val_loss: 3.7479 - val_accuracy: 0.3567
# Epoch 13/50
# 601/601 [==============================] - 186s 309ms/step - loss: 0.2449 - accuracy: 0.9113 - val_loss: 1.3952 - val_accuracy: 0.6596
# Epoch 14/50
# 601/601 [==============================] - 185s 309ms/step - loss: 0.2168 - accuracy: 0.9246 - val_loss: 2.2095 - val_accuracy: 0.5086
# Epoch 15/50
# 601/601 [==============================] - 188s 312ms/step - loss: 0.1868 - accuracy: 0.9342 - val_loss: 1.9606 - val_accuracy: 0.5592
# Epoch 16/50
# 601/601 [==============================] - 187s 311ms/step - loss: 0.1632 - accuracy: 0.9431 - val_loss: 1.8836 - val_accuracy: 0.5374
# Epoch 17/50
# 601/601 [==============================] - 183s 304ms/step - loss: 0.1574 - accuracy: 0.9459 - val_loss: 1.4584 - val_accuracy: 0.6150
# Epoch 18/50
# 601/601 [==============================] - 173s 287ms/step - loss: 0.1384 - accuracy: 0.9516 - val_loss: 2.6487 - val_accuracy: 0.4083
# Epoch 19/50
# 601/601 [==============================] - 177s 294ms/step - loss: 0.1263 - accuracy: 0.9568 - val_loss: 1.3401 - val_accuracy: 0.6177
# Epoch 20/50
# 601/601 [==============================] - 184s 305ms/step - loss: 0.1140 - accuracy: 0.9629 - val_loss: 5.5751 - val_accuracy: 0.2863
# Epoch 21/50
# 601/601 [==============================] - 183s 305ms/step - loss: 0.1103 - accuracy: 0.9643 - val_loss: 1.9762 - val_accuracy: 0.5980
# Epoch 22/50
# 601/601 [==============================] - 184s 306ms/step - loss: 0.1052 - accuracy: 0.9650 - val_loss: 0.4335 - val_accuracy: 0.8811
# Epoch 23/50
# 601/601 [==============================] - 189s 315ms/step - loss: 0.1010 - accuracy: 0.9667 - val_loss: 1.0805 - val_accuracy: 0.7545
# Epoch 24/50
# 601/601 [==============================] - 194s 323ms/step - loss: 0.0974 - accuracy: 0.9684 - val_loss: 4.2682 - val_accuracy: 0.3390
# Epoch 25/50
# 601/601 [==============================] - 191s 319ms/step - loss: 0.0919 - accuracy: 0.9694 - val_loss: 2.8642 - val_accuracy: 0.4951
# Epoch 26/50
# 601/601 [==============================] - 186s 309ms/step - loss: 0.0840 - accuracy: 0.9729 - val_loss: 0.7074 - val_accuracy: 0.7920
# Epoch 27/50
# 601/601 [==============================] - 184s 305ms/step - loss: 0.0806 - accuracy: 0.9738 - val_loss: 2.7446 - val_accuracy: 0.5299
# Epoch 28/50
# 601/601 [==============================] - 183s 304ms/step - loss: 0.0746 - accuracy: 0.9765 - val_loss: 1.9896 - val_accuracy: 0.6504
# Epoch 29/50
# 601/601 [==============================] - 192s 319ms/step - loss: 0.0752 - accuracy: 0.9763 - val_loss: 1.7300 - val_accuracy: 0.6371
# Epoch 30/50
# 601/601 [==============================] - 195s 325ms/step - loss: 0.0738 - accuracy: 0.9777 - val_loss: 0.8869 - val_accuracy: 0.7943
# Epoch 31/50
# 601/601 [==============================] - 194s 323ms/step - loss: 0.0728 - accuracy: 0.9764 - val_loss: 0.4587 - val_accuracy: 0.8803
# Epoch 32/50
# 601/601 [==============================] - 192s 320ms/step - loss: 0.0706 - accuracy: 0.9781 - val_loss: 3.0060 - val_accuracy: 0.4816
# Epoch 33/50
# 601/601 [==============================] - 182s 303ms/step - loss: 0.0686 - accuracy: 0.9790 - val_loss: 0.9316 - val_accuracy: 0.7331
# Epoch 34/50
# 601/601 [==============================] - 183s 304ms/step - loss: 0.0587 - accuracy: 0.9819 - val_loss: 0.6528 - val_accuracy: 0.8368
# Epoch 35/50
# 601/601 [==============================] - 183s 305ms/step - loss: 0.0590 - accuracy: 0.9811 - val_loss: 1.4457 - val_accuracy: 0.6998
# Epoch 36/50
# 601/601 [==============================] - 175s 291ms/step - loss: 0.0627 - accuracy: 0.9809 - val_loss: 1.6186 - val_accuracy: 0.6477
# Epoch 37/50
# 601/601 [==============================] - 225s 374ms/step - loss: 0.0579 - accuracy: 0.9832 - val_loss: 1.3209 - val_accuracy: 0.7433
# Epoch 38/50
# 601/601 [==============================] - 183s 304ms/step - loss: 0.0578 - accuracy: 0.9818 - val_loss: 0.4497 - val_accuracy: 0.8903
# Epoch 39/50
# 601/601 [==============================] - 196s 327ms/step - loss: 0.0524 - accuracy: 0.9837 - val_loss: 2.1058 - val_accuracy: 0.5020
# Epoch 40/50
# 601/601 [==============================] - 187s 312ms/step - loss: 0.0566 - accuracy: 0.9835 - val_loss: 0.7376 - val_accuracy: 0.8314
# Epoch 41/50
# 601/601 [==============================] - 184s 307ms/step - loss: 0.0550 - accuracy: 0.9824 - val_loss: 0.1809 - val_accuracy: 0.9511
# Epoch 42/50
# 601/601 [==============================] - 185s 308ms/step - loss: 0.0544 - accuracy: 0.9834 - val_loss: 1.7853 - val_accuracy: 0.6192
# Epoch 43/50
# 601/601 [==============================] - 185s 307ms/step - loss: 0.0553 - accuracy: 0.9839 - val_loss: 0.9979 - val_accuracy: 0.7920
# Epoch 44/50
# 601/601 [==============================] - 190s 316ms/step - loss: 0.0482 - accuracy: 0.9858 - val_loss: 5.6016 - val_accuracy: 0.3440
# Epoch 45/50
# 601/601 [==============================] - 187s 311ms/step - loss: 0.0515 - accuracy: 0.9852 - val_loss: 1.6855 - val_accuracy: 0.7060
# Epoch 46/50
# 601/601 [==============================] - 185s 307ms/step - loss: 0.0437 - accuracy: 0.9857 - val_loss: 0.3692 - val_accuracy: 0.9103
# Epoch 47/50
# 601/601 [==============================] - 187s 311ms/step - loss: 0.0493 - accuracy: 0.9844 - val_loss: 0.8895 - val_accuracy: 0.8080
# Epoch 48/50
# 601/601 [==============================] - 189s 315ms/step - loss: 0.0426 - accuracy: 0.9868 - val_loss: 1.1221 - val_accuracy: 0.7976
# Epoch 49/50
# 601/601 [==============================] - 198s 330ms/step - loss: 0.0566 - accuracy: 0.9833 - val_loss: 1.0641 - val_accuracy: 0.7735
# Epoch 50/50
# 601/601 [==============================] - 199s 331ms/step - loss: 0.0389 - accuracy: 0.9882 - val_loss: 0.2452 - val_accuracy: 0.9386

# %%
# Evaluasi model
y_pred = model.predict(X_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_test, axis=1)
# Out:
# 151/151 [==============================] - 15s 89ms/step

# %%
# Confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %%
# Classification report
print(classification_report(y_true, y_pred_classes, target_names=le.classes_))
# Out:
#                      precision    recall  f1-score   support
#
# Ban Belakang Kempes       0.99      0.95      0.97      1201
#    Ban Depan Kempes       0.98      0.84      0.90      1201
#          Ban Normal       0.89      0.98      0.94      1201
#    Kedua Ban Kempes       0.90      0.99      0.94      1200
#
#            accuracy                           0.94      4803
#           macro avg       0.94      0.94      0.94      4803
#        weighted avg       0.94      0.94      0.94      4803

# %%
# Plotting training & validation accuracy values
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

# %%
# Plotting training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# Save the model for deployment
model.save('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/model_shuffle_150-10.keras')

# %%
# Load the trained model
model = tf.keras.models.load_model('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/model_shuffle_150-10.keras')

# %%
# Convert the model to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter._experimental_lower_tensor_list_ops = False
tflite_model = converter.convert()

# %%
# Save the TensorFlow Lite model to a file
with open('/content/drive/MyDrive/Skripsi_Aji Rahman Hakim/Data/model_shuffle_150-10.tflite', 'wb') as f:
    f.write(tflite_model)

print("Model has been converted to TensorFlow Lite and saved.")
# Out:
# Model has been converted to TensorFlow Lite and saved.
